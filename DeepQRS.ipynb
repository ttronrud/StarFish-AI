# %%
import wfdb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.utils import to_categorical
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
import random
import math

##MAIN CONSTANTS TO ADJUST
num_sec = 6 #length of time to send through model
fs = 360 #sample rate
min_RR = 0.3 #minimum length of time between Rs in seconds
#0.3 ~200bpm
####


abnormal = ['L','R','V','/','A','f','F','j','a','E','J','e','S']

data_path = 'MIT-BIH_Arrythm/'

# list of patients
pts = ['100','101','103','105','106',
       '108','109','111','112','113','114','115','116',
       '117','118','119','121','122','123','124','200',
       '201','202','203','205','207','208','209','210',
       '212','213','214','215','219','220','221',
       '222','223','228','230','231','232','233','234']

pt_files = [data_path + pt for pt in pts]
df = pd.DataFrame()

for pt in pts:
    file = data_path + pt
    annotation = wfdb.rdann(file, 'atr')
    sym = annotation.symbol
    
    values, counts = np.unique(sym, return_counts=True)
    df_sub = pd.DataFrame({'sym':values, 'val':counts, 'pt':[pt]*len(counts)})
    df = pd.concat([df, df_sub],axis = 0)

def wfdb_load_ecg(file):
    record = wfdb.rdrecord(file)
    annotation = wfdb.rdann(file, 'atr')
    
    # extract the signal
    p_signal = record.p_signal
    
    # verify frequency is 360
    assert record.fs == 360, 'sample freq is not 360'
    
    # extract symbols and annotation index
    atr_sym = annotation.symbol
    atr_sample = annotation.sample
    
    return p_signal, atr_sym, atr_sample 

def gen_dataset(pt_list, sample_sec = 3, fs=360., targets=abnormal + ['N'], drop_to = -1):
    N = int(sample_sec*fs)
    
    Xs = [] #signal samples
    Ys = [] #number of N annotations contained within the signal
    
    for pt in pt_list:
        sig,symbols,sym_sample = wfdb_load_ecg(pt)
        sig = sig[:,0]
        nuDim = int(math.floor(sig.shape[0]/N)) #how many recordings of length N can we get?
        numN = np.zeros(nuDim)
        #split the signal into equal chunks using reshape
        SplitSig = sig[:N*nuDim].reshape((nuDim,N))
        #now, get number of Ns within signal
        for inde, offset in enumerate(range(nuDim)):
            sym_fil = (sym_sample > offset*N)&(sym_sample < (offset+1)*N)
            _n = 0
            keeps = len(np.array(symbols)[sym_fil])
            if drop_to < 0: #can drop up to all
                keeps = len(np.array(symbols)[sym_fil])-np.random.randint(len(np.array(symbols)[sym_fil])-1)
            elif drop_to > 0:
                keeps = len(np.array(symbols)[sym_fil])-np.random.randint(drop_to)
            for i,s in enumerate(np.array(symbols)[sym_fil]):
                if i < keeps:
                    if np.isin(s,targets):
                        _n += 1
                else:
                    samnum = sym_sample[sym_fil][i]
                    SplitSig[inde][samnum-offset*N-75:] = 0
                    break
            #numN[inde] = _n
            ssig_baseline = np.convolve(SplitSig[inde],np.ones(64)/64., mode = 'same')
            debaselined_ssig = SplitSig[inde,:ssig_baseline.shape[0]] - ssig_baseline
            Xs.append(debaselined_ssig)
            Ys.append([_n])
    return np.array(Xs), np.array(Ys)
    
ssig,nN = gen_dataset(pt_files[:10],sample_sec=6)
ssig_nodrop,nN_nodrop = gen_dataset(pt_files[:10],sample_sec=6,drop_to=0)

# %%
basel = 50
for i,N in enumerate(nN[basel:basel+5]):
    plt.plot(ssig[basel+i])
    plt.text(50,0.5,str(N))
    plt.show()

Xtotal = np.reshape(ssig,(ssig.shape[0],ssig.shape[1],1))
Ytotal = np.array(nN)

Nrand = int(Xtotal.shape[0]/2)
print(Nrand)
#random training
#train_args = np.random.randint(Xtotal.shape[0], size=Nrand)
#targeted training
train_args = []
targets = range(1,15)
for t in targets:
    t_fil = (Ytotal-t == 0)
    tval = np.ones(Ytotal.shape)
    tval[~t_fil] = 0
    sel_args = np.flatnonzero(tval)
    end_bound = min(len(sel_args),Nrand/len(targets))
    for i,a in enumerate(sel_args):
        if i > end_bound:
            break
        train_args.append(a)
    
X_train_cnn = Xtotal[train_args]
Y_train_cnn = Ytotal[train_args]

X_valid_cnn = Xtotal
Y_valid_cnn = Ytotal

X_full = np.reshape(ssig_nodrop,(ssig_nodrop.shape[0],ssig_nodrop.shape[1],1))
Y_full = np.array(nN_nodrop)
# Out:
# 1500

# %%
model = Sequential()
#model.add(MaxPooling1D(pool_size=4, input_shape = (N,1))) #sigmoid
model.add(Conv1D(filters = 128, kernel_size = 32, activation = 'sigmoid', padding = "causal"))#, input_shape = (N,1)))
model.add(MaxPooling1D(pool_size=32))
model.add(Dropout(rate = 0.25))
model.add(Flatten())

#model.add(Dense(128, activation = 'sigmoid'))

model.add(Dense(64, activation = 'sigmoid'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1))#, activation = 'sigmoid'))

model.compile(
            loss = 'mean_absolute_percentage_error',#'mean_squared_error',#
            optimizer = 'nadam',
            metrics = ['mse'])

# %%
N = X_train_cnn[0].shape[0]
min_RR_samp = int(min_RR*fs)
print("Input size = %d\nPool layer size = %d"%(N,min_RR_samp))

model = Sequential()
model.add(Conv1D(filters = 128, kernel_size = 32, activation = 'relu', padding = "causal", input_shape = (N,1)))
model.add(MaxPooling1D(pool_size=min_RR_samp,padding="same"))
model.add(Conv1D(filters = 64, kernel_size = 8, activation = 'relu', padding = "causal"))
model.add(MaxPooling1D(pool_size=int(0.5*min_RR_samp),padding="same"))
model.add(Dropout(rate = 0.1))
model.add(Flatten())

#model.add(Dense(128, activation = 'sigmoid'))

model.add(Dense(64, activation = 'sigmoid'))
model.add(Dense(32, activation = 'relu'))
model.add(Dense(1))#, activation = 'sigmoid'))

model.compile(
            loss = 'mean_absolute_percentage_error',#'mean_squared_error',#
            optimizer = 'nadam',
            metrics = ['mse'])
# Out:
# Input size = 2160
# Pool layer size = 108

# %%
model.fit(X_train_cnn, Y_train_cnn, batch_size = 10, epochs= 100, verbose = 1)
model.save('keras_model.h5', include_optimizer=False)
# Out:
# Epoch 1/100
# 82/82 [==============================] - 2s 26ms/step - loss: 44.1161 - mse: 8.9123
# Epoch 2/100
# 82/82 [==============================] - 2s 20ms/step - loss: 21.1437 - mse: 2.1686
# Epoch 3/100
# 82/82 [==============================] - 2s 20ms/step - loss: 13.5857 - mse: 0.6745
# Epoch 4/100
# 82/82 [==============================] - 2s 21ms/step - loss: 12.2472 - mse: 0.5297
# Epoch 5/100
# 82/82 [==============================] - 2s 21ms/step - loss: 12.4767 - mse: 0.5470
# Epoch 6/100
# 82/82 [==============================] - 2s 20ms/step - loss: 11.3739 - mse: 0.4564
# Epoch 7/100
# 82/82 [==============================] - 2s 20ms/step - loss: 11.3263 - mse: 0.4331
# Epoch 8/100
# 82/82 [==============================] - 2s 25ms/step - loss: 10.8209 - mse: 0.4110
# Epoch 9/100
# 82/82 [==============================] - 2s 23ms/step - loss: 10.5266 - mse: 0.3959
# Epoch 10/100
# 82/82 [==============================] - 2s 22ms/step - loss: 10.7208 - mse: 0.4137
# Epoch 11/100
# 82/82 [==============================] - 2s 25ms/step - loss: 9.9827 - mse: 0.3400
# Epoch 12/100
# 82/82 [==============================] - 2s 27ms/step - loss: 10.0198 - mse: 0.3678
# Epoch 13/100
# 82/82 [==============================] - 2s 23ms/step - loss: 10.1769 - mse: 0.3507
# Epoch 14/100
# 82/82 [==============================] - 2s 26ms/step - loss: 9.5818 - mse: 0.3120
# Epoch 15/100
# 82/82 [==============================] - 2s 21ms/step - loss: 9.7252 - mse: 0.3176
# Epoch 16/100
# 82/82 [==============================] - 2s 21ms/step - loss: 8.8132 - mse: 0.2948
# Epoch 17/100
# 82/82 [==============================] - 2s 26ms/step - loss: 8.7568 - mse: 0.2696
# Epoch 18/100
# 82/82 [==============================] - 2s 27ms/step - loss: 9.0853 - mse: 0.3062
# Epoch 19/100
# 82/82 [==============================] - 2s 23ms/step - loss: 9.0658 - mse: 0.2883
# Epoch 20/100
# 82/82 [==============================] - 2s 25ms/step - loss: 8.6112 - mse: 0.2614
# Epoch 21/100
# 82/82 [==============================] - 2s 25ms/step - loss: 7.9324 - mse: 0.2381
# Epoch 22/100
# 82/82 [==============================] - 2s 26ms/step - loss: 8.3280 - mse: 0.2480
# Epoch 23/100
# 82/82 [==============================] - 2s 26ms/step - loss: 7.9172 - mse: 0.2245
# Epoch 24/100
# 82/82 [==============================] - 2s 24ms/step - loss: 7.3401 - mse: 0.2068
# Epoch 25/100
# 82/82 [==============================] - 2s 26ms/step - loss: 7.5268 - mse: 0.2165
# Epoch 26/100
# 82/82 [==============================] - 2s 29ms/step - loss: 7.4055 - mse: 0.2053
# Epoch 27/100
# 82/82 [==============================] - 2s 27ms/step - loss: 6.6832 - mse: 0.1787
# Epoch 28/100
# 82/82 [==============================] - 2s 27ms/step - loss: 6.8289 - mse: 0.1810
# Epoch 29/100
# 82/82 [==============================] - 2s 29ms/step - loss: 6.4027 - mse: 0.1700
# Epoch 30/100
# 82/82 [==============================] - 2s 25ms/step - loss: 6.3425 - mse: 0.1629
# Epoch 31/100
# 82/82 [==============================] - 2s 23ms/step - loss: 6.4070 - mse: 0.1698
# Epoch 32/100
# 82/82 [==============================] - 2s 27ms/step - loss: 6.4958 - mse: 0.1638
# Epoch 33/100
# 82/82 [==============================] - 2s 24ms/step - loss: 6.2035 - mse: 0.1512
# Epoch 34/100
# 82/82 [==============================] - 2s 23ms/step - loss: 6.5384 - mse: 0.1664
# Epoch 35/100
# 82/82 [==============================] - 2s 26ms/step - loss: 5.8203 - mse: 0.1399
# Epoch 36/100
# 82/82 [==============================] - 2s 21ms/step - loss: 6.1388 - mse: 0.1512: 0s - loss: 6.1042
# Epoch 37/100
# 82/82 [==============================] - 2s 22ms/step - loss: 6.3160 - mse: 0.1605
# Epoch 38/100
# 82/82 [==============================] - 2s 27ms/step - loss: 5.8984 - mse: 0.1398
# Epoch 39/100
# 82/82 [==============================] - 2s 22ms/step - loss: 5.6726 - mse: 0.1344
# Epoch 40/100
# 82/82 [==============================] - 2s 23ms/step - loss: 5.8450 - mse: 0.1455
# Epoch 41/100
# 82/82 [==============================] - 2s 29ms/step - loss: 5.4497 - mse: 0.1295
# Epoch 42/100
# 82/82 [==============================] - 2s 22ms/step - loss: 5.8656 - mse: 0.1485
# Epoch 43/100
# 82/82 [==============================] - 2s 22ms/step - loss: 5.6043 - mse: 0.1342
# Epoch 44/100
# 82/82 [==============================] - 2s 27ms/step - loss: 5.3019 - mse: 0.1187
# Epoch 45/100
# 82/82 [==============================] - 2s 24ms/step - loss: 5.1842 - mse: 0.1249
# Epoch 46/100
# 82/82 [==============================] - 2s 22ms/step - loss: 5.1731 - mse: 0.1249
# Epoch 47/100
# 82/82 [==============================] - 2s 26ms/step - loss: 5.3441 - mse: 0.1298
# Epoch 48/100
# 82/82 [==============================] - 2s 25ms/step - loss: 5.4626 - mse: 0.1323
# Epoch 49/100
# 82/82 [==============================] - 2s 23ms/step - loss: 5.1595 - mse: 0.1213
# Epoch 50/100
# 82/82 [==============================] - 2s 25ms/step - loss: 5.1903 - mse: 0.1174
# Epoch 51/100
# 82/82 [==============================] - 2s 23ms/step - loss: 4.9019 - mse: 0.1145
# Epoch 52/100
# 82/82 [==============================] - 2s 22ms/step - loss: 4.4709 - mse: 0.1059
# Epoch 53/100
# 82/82 [==============================] - 2s 24ms/step - loss: 4.8721 - mse: 0.1220
# Epoch 54/100
# 82/82 [==============================] - 2s 26ms/step - loss: 4.5876 - mse: 0.1143
# Epoch 55/100
# 82/82 [==============================] - 2s 24ms/step - loss: 4.4577 - mse: 0.1026
# Epoch 56/100
# 82/82 [==============================] - 2s 27ms/step - loss: 4.5303 - mse: 0.1054
# Epoch 57/100
# 82/82 [==============================] - 2s 26ms/step - loss: 4.5940 - mse: 0.1209
# Epoch 58/100
# 82/82 [==============================] - 2s 22ms/step - loss: 4.4702 - mse: 0.1078
# Epoch 59/100
# 82/82 [==============================] - 2s 22ms/step - loss: 4.6650 - mse: 0.1188: 0s - loss: 4.7382 - mse:
# Epoch 60/100
# 82/82 [==============================] - 2s 26ms/step - loss: 4.4240 - mse: 0.0994
# Epoch 61/100
# 82/82 [==============================] - 2s 22ms/step - loss: 4.0450 - mse: 0.1010
# Epoch 62/100
# 82/82 [==============================] - 2s 24ms/step - loss: 4.1722 - mse: 0.0999
# Epoch 63/100
# 82/82 [==============================] - 2s 27ms/step - loss: 4.2427 - mse: 0.1001
# Epoch 64/100
# 82/82 [==============================] - 2s 24ms/step - loss: 4.1372 - mse: 0.0998
# Epoch 65/100
# 82/82 [==============================] - 2s 23ms/step - loss: 4.2123 - mse: 0.1047
# Epoch 66/100
# 82/82 [==============================] - 2s 26ms/step - loss: 4.1115 - mse: 0.1010
# Epoch 67/100
# 82/82 [==============================] - 2s 22ms/step - loss: 3.8299 - mse: 0.0934
# Epoch 68/100
# 82/82 [==============================] - 2s 23ms/step - loss: 3.6491 - mse: 0.0904
# Epoch 69/100
# 82/82 [==============================] - 2s 27ms/step - loss: 3.6652 - mse: 0.0794
# Epoch 70/100
# 82/82 [==============================] - 2s 22ms/step - loss: 3.9703 - mse: 0.1034
# Epoch 71/100
# 82/82 [==============================] - 2s 25ms/step - loss: 3.8582 - mse: 0.0953
# Epoch 72/100
# 82/82 [==============================] - 2s 29ms/step - loss: 3.8343 - mse: 0.0986
# Epoch 73/100
# 82/82 [==============================] - 2s 23ms/step - loss: 3.6294 - mse: 0.0862
# Epoch 74/100
# 82/82 [==============================] - 2s 21ms/step - loss: 4.1260 - mse: 0.0987
# Epoch 75/100
# 82/82 [==============================] - 2s 26ms/step - loss: 3.6492 - mse: 0.0905
# Epoch 76/100
# 82/82 [==============================] - 2s 22ms/step - loss: 3.3973 - mse: 0.0812
# Epoch 77/100
# 82/82 [==============================] - 2s 22ms/step - loss: 3.5585 - mse: 0.0856
# Epoch 78/100
# 82/82 [==============================] - 2s 27ms/step - loss: 3.4349 - mse: 0.0868
# Epoch 79/100
# 82/82 [==============================] - 2s 22ms/step - loss: 3.2588 - mse: 0.0803
# Epoch 80/100
# 82/82 [==============================] - 2s 24ms/step - loss: 3.3405 - mse: 0.0831
# Epoch 81/100
# 82/82 [==============================] - 2s 26ms/step - loss: 3.3842 - mse: 0.0891
# Epoch 82/100
# 82/82 [==============================] - 2s 24ms/step - loss: 3.3337 - mse: 0.0820
# Epoch 83/100
# 82/82 [==============================] - 2s 24ms/step - loss: 3.2744 - mse: 0.0857
# Epoch 84/100
# 82/82 [==============================] - 2s 26ms/step - loss: 3.2283 - mse: 0.0856
# Epoch 85/100
# 82/82 [==============================] - 2s 22ms/step - loss: 3.1258 - mse: 0.0824
# Epoch 86/100
# 82/82 [==============================] - 2s 21ms/step - loss: 3.1560 - mse: 0.0790
# Epoch 87/100
# 82/82 [==============================] - 2s 23ms/step - loss: 3.1736 - mse: 0.0899
# Epoch 88/100
# 82/82 [==============================] - 2s 26ms/step - loss: 2.9313 - mse: 0.0810
# Epoch 89/100
# 82/82 [==============================] - 2s 22ms/step - loss: 2.7812 - mse: 0.0696
# Epoch 90/100
# 82/82 [==============================] - 2s 22ms/step - loss: 3.2258 - mse: 0.0953
# Epoch 91/100
# 82/82 [==============================] - 2s 25ms/step - loss: 2.6440 - mse: 0.0691
# Epoch 92/100
# 82/82 [==============================] - 2s 21ms/step - loss: 2.8488 - mse: 0.0766
# Epoch 93/100
# 82/82 [==============================] - 2s 23ms/step - loss: 2.8520 - mse: 0.0745
# Epoch 94/100
# 82/82 [==============================] - 2s 25ms/step - loss: 3.2192 - mse: 0.0859
# Epoch 95/100
# 82/82 [==============================] - 2s 21ms/step - loss: 3.1077 - mse: 0.0856
# Epoch 96/100
# 82/82 [==============================] - 2s 22ms/step - loss: 2.5164 - mse: 0.0599
# Epoch 97/100
# 82/82 [==============================] - 2s 28ms/step - loss: 2.6878 - mse: 0.0705
# Epoch 98/100
# 82/82 [==============================] - 2s 22ms/step - loss: 2.5609 - mse: 0.0702
# Epoch 99/100
# 82/82 [==============================] - 2s 21ms/step - loss: 2.4508 - mse: 0.0678
# Epoch 100/100
# 82/82 [==============================] - 2s 24ms/step - loss: 2.8176 - mse: 0.0792

# %%
y_train_preds_cnn = model.predict(X_train_cnn,verbose = 1)
y_valid_preds_cnn = model.predict(X_valid_cnn,verbose = 1) 
y_full_preds = model.predict(X_full,verbose = 1)

#Test with a single vector of zeros to see
#what the model returns
Y_test = model.predict(np.zeros((1,2160,1)))
print("Dummy input test -- zero input yields %.3f"%(Y_test))
# Out:
# 26/26 [==============================] - 1s 25ms/step
# 94/94 [==============================] - 2s 25ms/step
# 94/94 [==============================] - 2s 26ms/step
# Dummy input test -- zero input yields 0.138

# %%
f,axs = plt.subplots(11,1,figsize=(16,24))

axs[0].scatter(Y_valid_cnn,y_valid_preds_cnn, alpha=0.5,label="all")
axs[0].scatter(Y_full,y_full_preds, alpha=0.5,label="full")
axs[0].scatter(Y_train_cnn,y_train_preds_cnn, alpha=1,label="training")
axs[0].set_xlim(0,20)
axs[0].set_ylim(0,20)
axs[0].set_xlabel("True # of beats", fontsize=16)
axs[0].set_ylabel("NN Guesstimation", fontsize=16)
axs[0].plot([0,50],[0,50])
axs[0].legend()

_q = 1
for IND in np.random.randint(X_full.shape[0], size=10):
    axs[_q].plot(X_full[IND]) 
    axs[_q].text(50,1,"True:{:.1f}\nPred:{:.1f}".format(Y_full[IND][0],y_full_preds[IND][0]))
    _q += 1
    np.savetxt('test_dat_good.txt', X_full[IND], delimiter='\n',fmt='%.3f')

plt.tight_layout()
plt.show()

# %%
X_train_cnn.shape
